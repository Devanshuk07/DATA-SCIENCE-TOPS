# %%
# NESTING -IF CONDITION IN IF MEANS==NESTING
#  below is the given example...

# %%
age=int(input("Enter Your Age"))
if age>=18:
    if age>=71:       #Nesting
        print("You Cannot Drive,SORRY")
    else:
        print("You Can Drive")
else:
    print("You are Underage, GET LOST")
# Out:
# Enter Your Age 12
# You are Underage, GET LOST
