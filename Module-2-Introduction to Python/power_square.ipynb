# %%
num=int(input('Enter a Number Which You want Sqare :'))
result=pow(num,2) #when you want power of anything write POW before the thing you want,,,2 is for square that is mandatory
print(result)
# Out:
# Enter a Number Which You want Sqare : 4
# 16
