# %%
amountbal=50000
a=int(input("Enter Your Account no :"))
b=int(input("Enter Your Pin :"))
c=int(input("Enter Withdrawal :"))
d=amountbal-c
print("Your Remaining Balance Is",d,"In your Account")
# Out:
# Enter Your Account no : 123433334443
# Enter Your Pin : 1997
# Enter Withdrawal : 20000
# Your Remaining Balance Is 30000 In your Account
