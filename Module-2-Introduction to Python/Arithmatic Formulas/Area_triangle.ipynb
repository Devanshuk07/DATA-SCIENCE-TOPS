# %%
#Area Of Triangle
base=int(input('BASE OF TRIANGLE :'))
height=int(input('BASE OF HEIGHT :'))
area=1/2*base*height
print('AREA OF TRIANGLE IS',area)
# Out:
# BASE OF TRIANGLE : 30
# BASE OF HEIGHT : 50
# AREA OF TRIANGLE IS 750.0
