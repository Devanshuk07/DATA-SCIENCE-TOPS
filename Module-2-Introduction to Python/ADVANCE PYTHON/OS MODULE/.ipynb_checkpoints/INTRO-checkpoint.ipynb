# %%
'''OS HANDELING IS USED TO MAKE DIRECTORY(FOLDER), DELETE DIRECTORY(FOLDER) AND ALSO REMOVE FILE.
IT IS MANDATORY TO WRITE IMPORT OS.
NOW TO CREATE =MKDIR(NAME_OF_DIRECTRY).
TO REMOVE FILE OR DIRCTRY =RMDIR(NAME_OF_DIRECTORY).
FOR EVERYTHING ELSE LIKE TO WRITE/READ FILE HANDELING IS USED NO NEED FOR OS.
YES BUT TO DELETE THE FILE OS IS REQUIRED.'''
