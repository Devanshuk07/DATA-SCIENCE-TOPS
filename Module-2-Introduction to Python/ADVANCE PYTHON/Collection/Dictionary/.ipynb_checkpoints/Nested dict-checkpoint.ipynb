# %%
#NESTED DICTIONARY MEANS IN DICT ,DICT IS PRESENT.

# %%
#EXAMPLES:-
root={"name":"RUTVI",
     "score":{      #nested dictionary.
    "chem":90,
    "maths":99,
    "sci":98,
     },           # , is nessecary.
      "roll":17,
}

print(root)
print(root["score"])
# Out:
# {'name': 'RUTVI', 'score': {'chem': 90, 'maths': 99, 'sci': 98}, 'roll': 17}
# {'chem': 90, 'maths': 99, 'sci': 98}
