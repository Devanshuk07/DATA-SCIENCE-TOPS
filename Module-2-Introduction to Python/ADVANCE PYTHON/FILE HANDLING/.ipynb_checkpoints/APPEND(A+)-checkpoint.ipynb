# %%
# file handeling open file:-(A+--> READ AND APPEND AT THE END OF FILE)
a=open("text2.txt","a+")
if a:
    c="hello bhai kd"
    print(a.write(c))
    print("WRITTEN SUCCESSFULLY")
else:
    print("ERROR")
# Out:
# 13
# WRITTEN SUCCESSFULLY
