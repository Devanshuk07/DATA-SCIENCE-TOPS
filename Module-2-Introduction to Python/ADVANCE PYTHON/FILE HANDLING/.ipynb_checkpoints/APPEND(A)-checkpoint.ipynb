# %%
# file handeling open file:-(A-->TO APPEND(ADD NEW) IN ORIGINAL FILE AND THAT TOO AT THE LAST ONLY)
#IT ALSO CREATE THE NEW FILE IF FILE YOU GIVE NOT FOUND.

a=open("open.txt","a")
b="HI KD"
print(a.write(b))
# Out:
# 5

# %%
'''NOTE--> APPEND+ ALWAYS ADD AT THE END. IT ALSO ADD AS MANY TIME YOU RUN THE CODE SO JUST RUN ONLY 1 TIME.'''
