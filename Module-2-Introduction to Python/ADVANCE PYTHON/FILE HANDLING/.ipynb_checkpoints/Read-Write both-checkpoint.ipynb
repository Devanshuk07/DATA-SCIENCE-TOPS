# %%
# W--> CREATE THE FILE:-
file=open("STRUCTURE_DATA","w")
print("file opened and created")
# Out:
# file opened and created

# %%
# WE WROTE SOMETHING IN THE FILE:-
file=open("STRUCTURE_DATA","w")
txt="STRUCTURED FILE CREATED AND OPENED BY THE USER"
result=file.write(txt)
print(result)
# Out:
# 46

# %%
# TO READ ONLY FILE WHATS WRITTEN IN THE FILE:-
file=open("STRUCTURE_DATA","r")
result=file.read()
print(result)
# Out:
# STRUCTURED FILE CREATED AND OPENED BY THE USER

# %%
#YOU CAN GIVE LIMITATION OF READING IN FILES:-
file=open("STRUCTURE_DATA","r")
result=file.read(24)          # 24 means first 24 charactors printed
print(result)
# Out:
# STRUCTURED FILE CREATED

# %%
#USING TRY EXCEPTIONAL METHOD FOR THIS:-
file=open("STRUCTURE_DATA","r")
result=file.read()
try:
    a=str(input("ENTER THE WORD/LETTER YOU WANT TO CHECK :")).upper()
    if a in result:
        print("YES IT IS THERE")
    else:
        print("NO SUCH WORDS")
except:                                         # EXCEPT WILL ONLY WORKS IF IT ORIGINALLY GIVES ERROR NOT IF YOU WANT TO PRINT EXCEPT.
    print("THERE IS ERROR IN WRITING...")
# Out:
# ENTER THE WORD/LETTER YOU WANT TO CHECK : FILE
# YES IT IS THERE

# %%
try:
    file=open("STRUCTURE_DATA","r")
    #txt=input("ENTER A NAME :-")           # HERE WE HAVE COMMENT THE TXT USER INPUT SO IT WILL GENERATE ERROR.
    result=file.read(txt)
except:
    print("ERROR")
else:
    print("FILE READ SUCCESSFULLY")
finally:
    file.close()
# Out:
# ERROR

# %%
# WORKING WITH EXCEPT:-
a=int(input("ENTER VALUE OF A:-"))
b=int(input("ENTER VALUE OF B:-"))
try:
    c=a/b      # YOU HAVE TO GIVE CONDITION INNER OF TRY....
    print("YOUR RESULT OF DIVISION IS :-",c)
except:
    print("ERROR !!! NO DIVISION CAN BE PERFORMED")
else:
    print("DIVISION WAS HARD BUT I DID")
finally:
    print("THANKS FOR USING ME & TRUSTING ME....")
