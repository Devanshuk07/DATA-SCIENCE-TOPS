# %%
def student_info(name, age, grade):
    print(f"Name: {name}")
    print(f"Age: {age}")
    print(f"Grade: {grade}")

# Calling function using keyword arguments
student_info(age=15, name="Alice", grade="7th")
# Out:
# Name: Alice
# Age: 15
# Grade: 7th
