# %%
# Initial assignment
x = 10
print("Initial value of x:", x)

# Reassignment
x = 25
print("Value of x after reassignment:", x)

# Reassign with a different data type
x = "Hello"
print("Value of x after changing data type:", x)
# Out:
# Initial value of x: 10
# Value of x after reassignment: 25
# Value of x after changing data type: Hello
