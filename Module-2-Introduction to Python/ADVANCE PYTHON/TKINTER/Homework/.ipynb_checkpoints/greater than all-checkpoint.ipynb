# %%
a=int(input("ENTER THE NUMBER A :"))
b=int(input("ENTER THE NUMBER B :"))
c=int(input("ENTER THE NUMBER C :"))
if a>b and a>c:
    print("A IS GREATER")
elif b>a and b>c:
    print("B IS GREATER")
elif a==b==c:
    print("ALL ARE EQUAL")
else:
    print("C IS GREATER")
