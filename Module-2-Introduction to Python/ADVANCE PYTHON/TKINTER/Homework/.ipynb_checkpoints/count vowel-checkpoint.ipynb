# %%
a=['a','e','i','o','u']
b=str(input("ENTER A SENTENCE :"))
count=0
for i in b:   # i is variable--for each loop it hold 1 charactor from the string.means 1st devanshu d then e then v like this
    if i in a: # if it i get vowel it goes to count and then count store 1 then again if i get other it again go to count then count get increse to 2 like this it stores total vowels in string given by user.
        count=count+1
print(count)
# Out:
# ENTER A SENTENCE : devanshu
# 3
