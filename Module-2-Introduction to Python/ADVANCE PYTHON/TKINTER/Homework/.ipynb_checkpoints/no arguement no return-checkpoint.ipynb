# %%
def greet():
    print("Hello! Welcome to Python.")
    
greet()
# () inside nothing so no arguement
# Function body contains a print statement → no return value
# Out:
# Hello! Welcome to Python.
