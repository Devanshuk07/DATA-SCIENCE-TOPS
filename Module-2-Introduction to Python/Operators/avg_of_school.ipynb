# %%
math=int(input('MATHS MARK :'))
phy=int(input('PHYSICS MARKS :'))
his=int(input('HISTORY MARKS :'))
comp=int(input('COMPUTER MARKS :'))
sci=int(input('SCIENCE MARKS :'))
avg=(math+phy+his+comp+sci)/5
print('AVERAGE IS',avg)
perc=(math+phy+his+comp+sci)*100/500
print('PERCENTAGE IS',perc)
# Out:
# MATHS MARK : 90
# PHYSICS MARKS : 90
# HISTORY MARKS : 90
# COMPUTER MARKS : 90
# SCIENCE MARKS : 90
# AVERAGE IS 90.0
# PERCENTAGE IS 90.0
