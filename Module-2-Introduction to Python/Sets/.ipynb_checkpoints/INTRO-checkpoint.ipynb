# %%
'''WHAT IS SET:- 
SET IS THE COLLECTION OF THE UNORDERED ITEMS.
EACH ELEMENT IN THE SET MUST BE UNIQUE & IMMUTABLE'''

# %%
collection={1,2,3,4,5,"hello","devanshu","devanshu"}
print(collection)
print(type(collection))
print(len(collection))      # no repetaion is taken.
# Out:
# {1, 2, 3, 4, 5, 'devanshu', 'hello'}
# <class 'set'>
# 7
