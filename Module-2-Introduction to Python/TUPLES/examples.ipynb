# %%
# user input 3 movies name then store it in list.
a=(input("Enter the best sci.fi movie you like :"))
b=(input("Enter the best horror movie you like :"))
c=(input("Enter the best anime movie you like :"))
list=[a,b,c]
print(list)
# Out:
# Enter the best sci.fi movie you like : stranger things
# Enter the best horror movie you like : the conjuring part1
# Enter the best anime movie you like : zootopis
# ['stranger things', 'the conjuring part1', 'zootopis']

# %%
# other method to write the same program
movies=[]
movies.append(input("ENTER 1st MOVIE :"))
movies.append(input("ENTER 2nd MOVIE :"))
movies.append(input("ENTER 3rd MOVIE :"))
print(movies)
# Out:
# ENTER 1st MOVIE : zoo
# ENTER 2nd MOVIE : me
# ENTER 3rd MOVIE : i me and irene
# ['zoo', 'me', 'i me and irene']

# %%
#Sorting acending order

list=['a','c','k','u','l','s','u','w','p','q','x','r']
list.sort()
print(list)
# Out:
# ['a', 'c', 'k', 'l', 'p', 'q', 'r', 's', 'u', 'u', 'w', 'x']
