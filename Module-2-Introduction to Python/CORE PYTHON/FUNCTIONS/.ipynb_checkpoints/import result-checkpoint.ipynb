# %%
import comp
call1=comp.add(10,20)
call2=comp.sub(10,20)
call3=comp.mult(10,20)
call4=comp.div(10,20)

print(call1)
print(call2)
print(call3)
print(call4)

''' THE SAME PROGRAM WILL RUN IN PYCHARM AND VISUAL STUDIO CODE ALSO.
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import comp
#       2 call=comp.add(10,20)
#       3 print(call)
#
# ModuleNotFoundError: No module named 'comp'
