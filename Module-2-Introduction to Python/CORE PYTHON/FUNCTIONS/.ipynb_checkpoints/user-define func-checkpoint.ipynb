# %%
'''USER DEFINE FUNCTION:-
ARE THE FUNCTION WHICH USER DEFINE ACCORDING TO HIS NEED.'''

# %%
# EXAMPLE:-
def cal(a,b):       #cal is a user define function.
    sum=a+b
    print(sum)

cal(90,20)
# Out:
# 110
