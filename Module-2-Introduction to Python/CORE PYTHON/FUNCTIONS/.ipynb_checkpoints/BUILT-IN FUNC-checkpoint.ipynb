# %%
''' SOME FUNCTION IN PYTHON ARE BUILT IN FUNCTIONS
SUCH AS:-
--PRINT()
--LEN()
--TYPE()
--RANGE()
'''

# %%
#PRINT IN:-
print("DEVANSHU", end=" ")     #,end=" " is used to print in a line.
print("IS HERO")
# Out:
# DEVANSHU IS HERO

# %%
# LEN():-
a="my name is enthony gonzalwis.I am alone in world"
print(len(a))
# Out:
# 48

# %%
#TYPE():-
a=2.22
b=90
c=True
d="i am alone"
print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'float'>
# <class 'int'>
# <class 'bool'>
# <class 'str'>

# %%
# RANGE():-
for i in range(0,5,2):     #(start,stop,step)
    print("KD")
# Out:
# KD
# KD
# KD
