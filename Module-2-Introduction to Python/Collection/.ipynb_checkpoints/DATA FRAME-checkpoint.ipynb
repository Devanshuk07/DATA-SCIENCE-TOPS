# %%
'''DATA FRAME : IT IS USED TO GIVE A TABULAR LAYOUT.
DATA IS A COLLECTION OF INFORMATION.
DATA IS TWO TYPE...
1)STRUCTURED  2)UNSTRUCTURED
STRUCTURED DATA: IT IS USED TO FORM TABLES AND CSV(COMMA SEPERATED VALUES) AND EXCEL.
UNSTRUCTURED DATA: IT IS IN FORM OF IMAGES/TEXT/VIDEOS.
DATA FRAME TAKE A DATA IN STRUCTURED FORMAT.
INSTALL A LIBRARIES OF PANDA.

# %%
import pandas as pd   #in place of pd you can write anything for sort form of pandas.
food={
    "foodname":["pizza","burgar","manchuriyan","gulabjamun"],
    "wastage":["20kg","30kg","5kg","2kg"],
    "quantity":[100,120,80,50],
}
a=pd.DataFrame(food,index=[1,2,3,4])
print(a)
# Out:
#       foodname wastage  quantity
# 1        pizza    20kg       100
# 2       burgar    30kg       120
# 3  manchuriyan     5kg        80
# 4   gulabjamun     2kg        50
