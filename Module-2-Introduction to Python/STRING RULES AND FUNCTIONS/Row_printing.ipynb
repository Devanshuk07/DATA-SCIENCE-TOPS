# %%
print('hi my name is devanshu
i am from rajkot
and i love pizza
i like to play gitar')
# Out:
#   Cell In[1], line 1
#     print('hi my name is devanshu
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print('''hi my name is devanshu
i am from rajkot
and i love pizza
i like to play gitar ''') # with ''' you can print the same lines in different rows.
# Out:
# hi my name is devanshu
# i am from rajkot
# and i love pizza
# i like to play gitar
