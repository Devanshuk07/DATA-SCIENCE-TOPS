# %%
#compound interest
#CI= P*(1+R/100)pow(T)
P=float(input('ENTER PRINCIPAL :'))
R=float(input('ENTER RATE :'))
T=float(input('ENTER TIME :'))
CI= P*(pow((1+R/100),T))
print(CI)
# Out:
# ENTER PRINCIPAL : 50000
# ENTER RATE : 20
# ENTER TIME : 5
# 124415.99999999997
