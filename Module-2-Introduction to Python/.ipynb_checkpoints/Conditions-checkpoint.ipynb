# %%
'''Conditions In python
   Type of Conditions

    a) if
    b) if else
    c) if elif
    d) switch (not used in Python)
    
'''
"""IF FORMAT:-
    if condition:
       statement(print)

# %%
#Example of IF

a=10
b=5
if a>b:     # : is necessary after condition(a>b)
 print("a is greater than b")    # always space is required when used if statement and then giving statement
# Out:
# a is greater than b

# %%
''' if else statement Format:

if Condition:
  statement()
else:
  statement()

'''

# %%
#Example of IF ELSE

a=20
b=50
if a<b:
    print("A is LESS than b")
else:
 print("B  is MORE than A")
# Out:
# A is LESS than b

# %%
a=int(input("Please Enter Your Age :"))
if a>=18:
 print("You Are Eligible For Voting")
else: print("You Are not Eligible To Voting")
# Out:
# Please Enter Your Age : 12
# You Are not Eligible To Voting

# %%
''' IF ELIF Statement FORMAT

if condition:
 print
elif condition:
 print
elif condition:
 print
elif condition
 print
.....       You can input this way as many condition as you want.

'''

# %%
a=int(input("Enter Your Maths Marks :"))
if a>=80:
    print("You Passed With A GRADE, CONGRATULATION")
elif 50<=a<=79:
 print("You Passes with B CLASS")
elif 35<=a<=49:
    print("You Just PASSED, WORK HARD IDIOT")
elif a<=34:
    print("YOU FAILED GET LOST")
