# %%
print("hello devanshu",end="")
print(" hello brijesh",end="")
print(" hello aayushi")
#Here end="" is used in print() to print in a row.
# Out:
# hello devanshu hello brijesh hello aayushi

# %%
#What is variable : A variable is stored in form of data.
#A variablee is just like container where we store information about data.
#In python there is no need to define identifier to declare variable.
#A variables must follow some rules to define.

#1) not need to declare identifier.
#2)Any variables can start with _underscore or with any character
    # _name="devanshu"
    # abc="devanshu"
#3)Any variable cannot start with numbers.
    # 3a="deva" //wrong
#4)some reserve words that is used as function in python cannot be used
    # if="deva"  //wrong
    # for="deva" //wrong
#5)any variable cannot accept blank-space.
    # a b="deva"  //wrong

# %%
a=22
b=33
c=44
print(a,b,c)
# Out:
# 22 33 44

# %%
a=55.5
b=90
c='deva'
d="justin"
print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'float'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
