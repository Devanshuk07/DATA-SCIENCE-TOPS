# %%
sale=int(input("The sale for the year is :"))
region=(input("The region of the perticular sale is :"))
discount=int(input("The discount for the perticular sale is :"))
output=(sale*discount)/100
output2=(sale-output)
print("Your sale for year is :",output2)
# Out:
# The sale for the year is : 30
# The region of the perticular sale is : gj
# The discount for the perticular sale is : 2
# Your sale for year is : 29.4
