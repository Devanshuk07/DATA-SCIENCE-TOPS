# %%
# what is boolean type : boolean is a data type of variables
# boolean store 2 type of data -1) True 2) False

# %%
a=True  # In True T must be capital and other in small
b=False # IN False F must be capital and others in small
print(a)
print(b)
print(type(a))
# Out:
# True
# False
# <class 'bool'>
