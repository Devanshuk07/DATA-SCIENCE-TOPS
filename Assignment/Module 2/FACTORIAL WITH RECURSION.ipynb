# %%
def fact(n):
    if n==0 or n==1:
        return 1       # We cannot use print instead of return in recursive functions because recursion needs returned values to compute results. print only displays output and returns None.
    else:
        return n*fact(n-1)
n=int(input("ENTER VALUE FOR FACTORIAL:-"))
fact(n)
