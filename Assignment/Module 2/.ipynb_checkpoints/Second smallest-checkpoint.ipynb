# %%
a=int(input("ENTER THE VALUE OF A :"))
b=int(input("ENTER THE VALUE OF B :"))
c=int(input("ENTER THE VALUE OF C :"))
if b<a<c or c>a>b:
    print("A IS SECOND SMALLEST")
elif a<b<c or a>b>c:
    print("B IS SECOND SMALLEST")
elif a<c<b or a>c>b:
    print("C IS SECOND SMALLEST")
# Out:
# ENTER THE VALUE OF A : 99
# ENTER THE VALUE OF B : 98
# ENTER THE VALUE OF C : 97
# B IS SECOND SMALLEST
