# %%
# List of tuples (key, value pairs)
list_1=[('a',1),('b',2),('c',3),('d',4)]    # each item inside the list is tuple.Each TUPLE contains key and its value.
b=dict(list_1)                              # converts a list of tuples into a dictionary
print("DICTIONARIES",b)
# Out:
# DICTIONARIES {'a': 1, 'b': 2, 'c': 3, 'd': 4}
