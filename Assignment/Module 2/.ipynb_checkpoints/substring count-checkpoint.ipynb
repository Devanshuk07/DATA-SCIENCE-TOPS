# %%
a=str(input("ENTER THE STRING"))
b=str(input("ENTER THE SUBSTRING"))
count=a.count(b)
print("OCCURANCE OF SUBSTRING IN STRING IS :",count)
# Out:
# ENTER THE STRING mittal shital and tital
# ENTER THE SUBSTRING t
# OCCURANCE OF SUBSTRING IN STRING IS : 5
