# %%
dict={                                        # {} in this if you only provide values its set not a dictionary
    21,66,51,99,276,6177,2736,9,22
}

print(sorted(dict))                           #sorted used to convert it into acending order.
# Out:
# [9, 21, 22, 51, 66, 99, 276, 2736, 6177]

# %%
dict={
    21,66,51,99,276,6177,2736,9,22
}
b=sorted(dict, reverse=True)            # reverse=True is used for decending order.
print(b)
# Out:
# [6177, 2736, 276, 99, 66, 51, 22, 21, 9]
