# %%
n=int(input("ENTER THE NUMBER TILL YOU WANT FIBONACCI SERIES :"))
a,b=0,1
for i in range(n):
    print(a)
    a,b=b,a+b    # python always evalute from right side.
    '''(b,a+b)=value=(1,1)
    then it will assign the value to a and b
    so now a=1 and b=1
    again:
    (b,a+b)=value=(1,2)
    so now a=1 and b=2
    remember we have print a and not b. only a is required for FIBONACCI SERIES.
    a=b      #you cannot use this because orinal value of a will be lost
    b=a+b'''
