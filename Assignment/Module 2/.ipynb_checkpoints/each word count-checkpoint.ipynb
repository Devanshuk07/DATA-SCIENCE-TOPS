# %%
a=str(input("ENTER THE STRING"))
b=str(input("ENTER THE SUBSTRING"))
count=a.count(b)
print("OCCURANCE OF SUBSTRING IN STRING IS :",count)
# Out:
# ENTER THE STRING hi my name is devanshu. hi devanshu are you devanshu
# ENTER THE SUBSTRING devanshu
# OCCURANCE OF SUBSTRING IN STRING IS : 3
