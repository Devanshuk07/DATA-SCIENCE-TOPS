# %%
a=int(input("ENTER THE VALUE OF A :"))
b=int(input("ENTER THE VALUE OF B :"))
c=a%b    #48%18=12
d=b%c    #18%12=6 answer.
print(d)
# Out:
# ENTER THE VALUE OF A : 48
# ENTER THE VALUE OF B : 18
# 6
