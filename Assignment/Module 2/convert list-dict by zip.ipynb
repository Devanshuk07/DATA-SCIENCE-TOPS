# %%
#HOW TO CONVERT A LIST INTO DICTIONARY:-
key=[1,2,3,4,5]
value=["devanshu","rajesh","meet","ruhi","vijay"]
a=dict(zip(key,value))
print(a)
print(type(a))
# Out:
# {1: 'devanshu', 2: 'rajesh', 3: 'meet', 4: 'ruhi', 5: 'vijay'}
# <class 'dict'>
