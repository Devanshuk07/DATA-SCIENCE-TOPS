# %%
# # what is comment in python
# there are basically 2 type of comment in python
# 1)Single-line Comment
# 2)Multi-line comment

# you can comment in single line by just #
# you can add multi comment by selecting all the line and then "CTRL?"
