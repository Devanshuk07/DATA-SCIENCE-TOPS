# %%
import numpy as np
#a=np.array([1,2,3,4,5,6])
a=list(input("GIVE THE ARRAY LIST:-"))   # list is for =to store value, to access length,to convert it into numpy array.
a=np.array(a)
b=a.reshape(2,3)       # reshape(2,3):- here 2=rows & 3=columns.
print(b)
