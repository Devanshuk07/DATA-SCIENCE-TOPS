# %%
print("NOTE--WE ONLY TAKE 2 ORDERS AT A TIME. THANK YOU !!")
print("%%%LIST OF ITEMS%%%%         PRIZE      CODE")
print("-PANEER TIKKA MASALA          350         1")
print("-PANEER BHURJEE               290         2")
print("-MASALA DHOSA                 120         3")
print("-CHEESE CHILLI MASALA DHOSA   150         4")
print("-CHINESE BHEL                 110         5")
print("-MANCHURIYAN DRY              90          6")
print("-GUJARATI THALI FIXED         250         7")
print("-UTTAPAM                      100         8")
print("-PANI PURI                    30          9")
print("-SHAHI AALOO                  70          10")

a1=350
a2=290
a3=120
a4=150
a5=110
a6=90
a7=250
a8=100
a9=30
a10=70

a=int(input("ENTER HOW MANY PEOPLE YOU ARE :"))

if a==1:
    b=int(input("ENTER THE CODE YOU WANT TO EAT :"))
    if b==1:
        print("YOU HAVE ORDERED--PANEER TIKKA MASALA")
        print("PRIZE = 350/-")
    elif b==2:
        print("YOU HAVE ORDERED--PANEER BHURJEE")
        print("PRIZE = 290/-")
    elif b==3:
        print("YOU HAVE ORDERED--MASALA DHOSA")
        print("PRIZE = 120/-")
    elif b==4:
        print("YOU HAVE ORDERED--CHEESE CHILI MASALA DHOSA")
        print("PRIZE = 150/-")
    elif b==5:
        print("YOU HAVE ORDERED--CHINESE BHEL")
        print("PRIZE = 110/-")
    elif b==6:
        print("YOU HAVE ORDERED--MANCHURIYAN DRY")
        print("PRIZE = 90/-")
    elif b==7:
        print("YOU HAVE ORDERED--GUJARATI THALI")
        print("PRIZE = 250/-")
    elif b==8:
        print("YOU HAVE ORDERED--UTTAPAM")
        print("PRIZE = 100/-")
    elif b==9:
        print("YOU HAVE ORDERED--PANI PURI")
        print("PRIZE = 30/-")
    elif b==10:
        print("YOU HAVE ORDERED--SHAHI AALOO")
        print("PRIZE = 70/-")
elif a==2:
    c=int(input("ENTER THE CODE YOU WANT TO EAT :"))
    d=int(input("ENTER THE CODE YOU WANT TO EAT :"))
    if c==1 and d==1:
        cd1=a1+a1
        print("YOU HAVE ORDERED--PANEER TIKKA MASALA X 2")
        print("TOTAL :",cd1)
    elif c==1 and d==2:
        cd2=a1+a2
        print("YOU HAVE ORDERED--PANEER TIKKA MASALA")
        print("YOU HAVE ORDERED--PANEER BHURJEE")
        print("TOTAL :",cd2)
    elif c==1 and d==3:
        cd3=a1+a3
        print("YOU HAVE ORDERED--PANEER TIKKA MASALA")
        print("YOU HAVE ORDERED--MASALA DHOSA")
        print("TOTAL :",cd3)
    elif c==1 and d==4:
        cd4=a1+a4
        print("YOU HAVE ORDERED--PANEER TIKKA MASALA")
        print("YOU HAVE ORDERED--CHEESE CHILI MASALA DHOSA")
        print("TOTAL :",cd4)
    elif c==1 and d==5:
        cd5=a1+a5
        print("YOU HAVE ORDERED--PANEER TIKKA MASALA")
        print("YOU HAVE ORDERED--CHINESE BHEL")
        print("TOTAL :",cd5)
    elif c==1 and d==6:
        cd6=a1+a6
        print("YOU HAVE ORDERED--PANEER TIKKA MASALA")
        print("YOU HAVE ORDERED--MANCHURIYAN DRY")
        print("TOTAL :",cd6)
    elif c==1 and d==7:
        cd7=a1+a7
        print("YOU HAVE ORDERED--PANEER TIKKA MASALA")
        print("YOU HAVE ORDERED--GUJARATI THALI")
        print("TOTAL :",cd7)
    elif c==1 and d==8:
        cd8=a1+a8
        print("YOU HAVE ORDERED--PANEER TIKKA MASALA")
        print("YOU HAVE ORDERED--UTTAPAM")
        print("TOTAL :",cd8)
    elif c==1 and d==9:
        cd9=a1+a9
        print("YOU HAVE ORDERED--PANEER TIKKA MASALA")
        print("YOU HAVE ORDERED--PANI PURI")
        print("TOTAL :",cd9)
    elif c==1 and d==10:
        cd10=a1+a10
        print("YOU HAVE ORDERED--PANEER TIKKA MASALA")
        print("YOU HAVE ORDERED--SHAHI AALOO")
        print("TOTAL :",cd10)

    elif c==2 and d==1:
        cd11=a2+a1
        print("YOU HAVE ORDERED--PANEER BHURJEE")
        print("YOU HAVE ORDERED--PANEER TIKKA MASALA")
        print("TOTAL :",cd11)
    elif c==2 and d==2:
        cd12=a2+a2
        print("YOU HAVE ORDERED--PANEER BHURJEE X 2")
        print("TOTAL :",cd12)
    elif c==2 and d==3:
        cd13=a2+a3
        print("YOU HAVE ORDERED--PANEER BHURJEE")
        print("YOU HAVE ORDERED--MASALA DHOSA")
        print("TOTAL :",cd13)
    elif c==2 and d==4:
        cd14=a2+a4
        print("YOU HAVE ORDERED--PANEER BHURJEE")
        print("YOU HAVE ORDERED--CHEESE CHILI MASALA DHOSA")
        print("TOTAL :",cd14)
    elif c==2 and d==5:
        cd15=a2+a1
        print("YOU HAVE ORDERED--PANEER BHURJEE")
        print("YOU HAVE ORDERED--CHINESE BHEL")
        print("TOTAL :",cd15)
    elif c==2 and d==6:
        cd16=a2+a6
        print("YOU HAVE ORDERED--PANEER BHURJEE")
        print("YOU HAVE ORDERED--MACHURIYAN DRY")
        print("TOTAL :",cd16)
    elif c==2 and d==7:
        cd18=a2+a7
        print("YOU HAVE ORDERED--PANEER BHURJEE")
        print("YOU HAVE ORDERED--GUJARATI THALI")
        print("TOTAL :",cd18)
    elif c==2 and d==8:
        cd19=a2+a8
        print("YOU HAVE ORDERED--PANEER BHURJEE")
        print("YOU HAVE ORDERED--PANEER TIKKA MASALA")
        print("TOTAL :",cd19)
    elif c==2 and d==9:
        cd20=a2+a9
        print("YOU HAVE ORDERED--PANEER BHURJEE")
        print("YOU HAVE ORDERED--PANI PURI")
        print("TOTAL :",cd20)
    elif c==2 and d==10:
        cd21=a2+a10
        print("YOU HAVE ORDERED--PANEER BHURJEE")
        print("YOU HAVE ORDERED--SHAHI AALOO")
        print("TOTAL :",cd21)
    elif c==3 and d==1:
        cd22=a3+a1
        print("YOU HAVE ORDERED--MASALA DHOSA")
        print("YOU HAVE ORDERED--PANEER TIKKA MASALA")
        print("TOTAL :",cd22)
    elif c==3 and d==2:
        cd23=a3+a2
        print("YOU HAVE ORDERED--MASALA DHOSA")
        print("YOU HAVE ORDERED--PANEER BHURJEE")
        print("TOTAL :",cd23)
    elif c==3 and d==3:
        cd24=a3+a3
        print("YOU HAVE ORDERED--MASALA DHOSA X 2")
        print("TOTAL :",cd24)
    elif c==3 and d==4:
        cd25=a3+a4
        print("YOU HAVE ORDERED--MASALA DHOSA")
        print("YOU HAVE ORDERED--CHEESE CHILI MASALA DHOSA")
        print("TOTAL :",cd25)
    elif c==3 and d==5:
        cd26=a3+a5
        print("YOU HAVE ORDERED--MASALA DHOSA")
        print("YOU HAVE ORDERED--CHINESE BHEL")
        print("TOTAL :",cd26)
    elif c==3 and d==6:
        cd27=a3+a6
        print("YOU HAVE ORDERED--MASALA DHOSA")
        print("YOU HAVE ORDERED--MANCHURIYAN SRY")
        print("TOTAL :",cd27)
    elif c==3 and d==7:
        cd17=a3+a7
        print("YOU HAVE ORDERED--MASALA DHOSA")
        print("YOU HAVE ORDERED--GUJARATI THALI")
        print("TOTAL :",cd17)
    elif c==3 and d==8:
        cd28=a3+a8
        print("YOU HAVE ORDERED--MASALA DHOSA")
        print("YOU HAVE ORDERED--UTTAPAM")
        print("TOTAL :",cd28)
    elif c==3 and d==9:
        cd29=a3+a9
        print("YOU HAVE ORDERED--MASALA DHOSA")
        print("YOU HAVE ORDERED--PANI PURI")
        print("TOTAL :",cd29)
    elif c==3 and d==10:
        cd30=a3+a10
        print("YOU HAVE ORDERED--MASALA DHOSA")
        print("YOU HAVE ORDERED--SHAHI AALOO")
        print("TOTAL :",cd30)
    elif c==4 and d==1:
        cd31=a4+a1
        print("YOU HAVE ORDERED--CHEESE CHILI MASALA DHOSA")
        print("YOU HAVE ORDERED--PANEER TIKKA MASALA")
        print("TOTAL :",cd31)
    elif c==4 and d==2:
        cd32=a4+a2
        print("YOU HAVE ORDERED--CHEESE CHILI MASALA DHOSA")
        print("YOU HAVE ORDERED--PANEER BHURJEE")
        print("TOTAL :",cd32)
    elif c==4 and d==3:
        cd33=a4+a3
        print("YOU HAVE ORDERED--CHEESE CHILI MASALA DHOSA")
        print("YOU HAVE ORDERED--MASALA DHOSA")
        print("TOTAL :",cd33)
    elif c==4 and d==4:
        cd34=a4+a4
        print("YOU HAVE ORDERED--CHEESE CHILI MASALA DHOSA X 2")
        print("TOTAL :",cd34)
    elif c==4 and d==5:
        cd35=a4+a5
        print("YOU HAVE ORDERED--CHEESE CHILI MASALA DHOSA")
        print("YOU HAVE ORDERED--CHINESE BHEL")
        print("TOTAL :",cd35)
    elif c==4 and d==6:
        cd36=a4+a6
        print("YOU HAVE ORDERED--CHEESE CHILI MASALA DHOSA")
        print("YOU HAVE ORDERED--MANCHURIYAN DRY")
        print("TOTAL :",cd36)
    elif c==4 and d==7:
        cd37=a4+a7
        print("YOU HAVE ORDERED--CHEESE CHILI MASALA DHOSA")
        print("YOU HAVE ORDERED--GUJARATI THALI")
        print("TOTAL :",cd37)
    elif c==4 and d==8:
        cd38=a4+a8
        print("YOU HAVE ORDERED--CHEESE CHILI MASALA DHOSA")
        print("YOU HAVE ORDERED--UTTAPAM")
        print("TOTAL :",cd38)
    elif c==4 and d==9:
        cd39=a4+a9
        print("YOU HAVE ORDERED--CHEESE CHILI MASALA DHOSA")
        print("YOU HAVE ORDERED--PANI PURI")
        print("TOTAL :",cd39)
    elif c==4 and d==10:
        cd40=a4+a10
        print("YOU HAVE ORDERED--CHEESE CHILI MASALA DHOSA")
        print("YOU HAVE ORDERED--SHAHI AALOO")
        print("TOTAL :",cd40)
    elif c==5 and d==1:
        cd41=a5+a1
        print("YOU HAVE ORDERED--CHINESE BHEL")
        print("YOU HAVE ORDERED--PANEER TIKKA MASALA")
        print("TOTAL :",cd41)
    elif c==5 and d==2:
        cd42=a5+a2
        print("YOU HAVE ORDERED--CHINESE BHEL")
        print("YOU HAVE ORDERED--PANEER BHURJEE")
        print("TOTAL :",cd42)
    elif c==5 and d==3:
        cd43=a5+a3
        print("YOU HAVE ORDERED--CHINESE BHEL")
        print("YOU HAVE ORDERED--MASALA DHOSA")
        print("TOTAL :",cd43)
    elif c==5 and d==4:
        cd44=a5+a4
        print("YOU HAVE ORDERED--CHINESE BHEL")
        print("YOU HAVE ORDERED--CHEESE CHILI MASLAA DHOSA")
        print("TOTAL :",cd44)
    elif c==5 and d==5:
        cd45=a5+a5
        print("YOU HAVE ORDERED--CHINESE BHEL X 2")
        print("TOTAL :",cd45)
    elif c==5 and d==6:
        cd46=a5+a6
        print("YOU HAVE ORDERED--CHINESE BHEL")
        print("YOU HAVE ORDERED--MANCHURIYAN DRY")
        print("TOTAL :",cd46)
    elif c==5 and d==7:
        cd47=a5+a7
        print("YOU HAVE ORDERED--CHINESE BHEL")
        print("YOU HAVE ORDERED--GUJARATI THALI")
        print("TOTAL :",cd47)
    elif c==5 and d==8:
        cd48=a5+a8
        print("YOU HAVE ORDERED--CHINESE BHEL")
        print("YOU HAVE ORDERED--UTTAPAM")
        print("TOTAL :",cd48)
    elif c==5 and d==9:
        cd49=a5+a9
        print("YOU HAVE ORDERED--CHINESE BHEL")
        print("YOU HAVE ORDERED--PANI PURI")
        print("TOTAL :",cd49)
    elif c==5 and d==10:
        cd50=a5+a10
        print("YOU HAVE ORDERED--CHINESE BHEL")
        print("YOU HAVE ORDERED--SHAHI AALOO")
        print("TOTAL :",cd50)
    elif c==6 and d==1:
        cd51=a6+a1
        print("YOU HAVE ORDERED--MANCHURIYAN DRY")
        print("YOU HAVE ORDERED--PANEER TIKKA MASALA")
        print("TOTAL :",cd51)
    elif c==6 and d==2:
        cd52=a6+a2
        print("YOU HAVE ORDERED--MANCHURIYAN DRY")
        print("YOU HAVE ORDERED--PANEER BHURJEE")
        print("TOTAL :",cd52)
    elif c==6 and d==3:
        cd53=a6+a3
        print("YOU HAVE ORDERED--MANCHURIYAN DRY")
        print("YOU HAVE ORDERED--MASALA DHOSA")
        print("TOTAL :",cd53)
    elif c==6 and d==4:
        cd54=a6+a4
        print("YOU HAVE ORDERED--MANCHURIYAN DRY")
        print("YOU HAVE ORDERED--CHEESE CHILI MASALA DHOSA")
        print("TOTAL :",cd54)
    elif c==6 and d==5:
        cd55=a6+a5
        print("YOU HAVE ORDERED--MANCHURIYAN DRY")
        print("YOU HAVE ORDERED--CHINESE BHEL")
        print("TOTAL :",cd55)
    elif c==6 and d==6:
        cd56=a6+a6
        print("YOU HAVE ORDERED--MANCHURIYAN DRY X 2")
        print("TOTAL :",cd56)
    elif c==6 and d==7:
        cd57=a6+a7
        print("YOU HAVE ORDERED--MANCHURIYAN DRY")
        print("YOU HAVE ORDERED--GUJARATI THALI FIXED")
        print("TOTAL :",cd57)
    elif c==6 and d==8:
        cd58=a6+a8
        print("YOU HAVE ORDERED--MANCHURIYAN DRY")
        print("YOU HAVE ORDERED--UTTAPAM")
        print("TOTAL :",cd58)
    elif c==6 and d==9:
        cd59=a6+a9
        print("YOU HAVE ORDERED--MANCHURIYAN DRY")
        print("YOU HAVE ORDERED--PANI PURI")
        print("TOTAL :",cd59)
    elif c==6 and d==10:
        cd60=a6+a10
        print("YOU HAVE ORDERED--MANCHURIYAN DRY")
        print("YOU HAVE ORDERED--SHAHI AALOO")
        print("TOTAL :",cd60)
    elif c==7 and d==1:
        cd61=a7+a1
        print("YOU HAVE ORDERED--GUJARATI THALI FIXED")
        print("YOU HAVE ORDERED--PANEER TIKKA MASALA")
        print("TOTAL :",cd61)
    elif c==7 and d==2:
        cd62=a7+a2
        print("YOU HAVE ORDERED--GUJARATI THALI FIXED")
        print("YOU HAVE ORDERED--PANEER BHURJEE")
        print("TOTAL :",cd62)
    elif c==7 and d==3:
        cd63=a7+a3
        print("YOU HAVE ORDERED--GUJARATI THALI FIXED")
        print("YOU HAVE ORDERED--MASALA DHOSA")
        print("TOTAL :",cd63)
    elif c==7 and d==4:
        cd64=a7+a4
        print("YOU HAVE ORDERED--GUJARATI THALI FIXED")
        print("YOU HAVE ORDERED--CHEESE CHILI MASALA DHOSA")
        print("TOTAL :",cd64)
    elif c==7 and d==5:
        cd65=a7+a5
        print("YOU HAVE ORDERED--GUJARATI THALI FIXED")
        print("YOU HAVE ORDERED--CHINESE BHEL")
        print("TOTAL :",cd65)
    elif c==7 and d==6:
        cd66=a7+a6
        print("YOU HAVE ORDERED--GUJARATI THALI FIXED")
        print("YOU HAVE ORDERED--MANCHURIYAN DRY")
        print("TOTAL :",cd66)
    elif c==7 and d==7:
        cd67=a7+a7
        print("YOU HAVE ORDERED--GUJARATI THALI FIXED X 2")
        print("TOTAL :",cd67)
    elif c==7 and d==8:
        cd68=a7+a8
        print("YOU HAVE ORDERED--GUJARATI THALI FIXED")
        print("YOU HAVE ORDERED--UTTAPAM")
        print("TOTAL :",cd68)
    elif c==7 and d==9:
        cd69=a7+a9
        print("YOU HAVE ORDERED--GUJARATI THALI FIXED")
        print("YOU HAVE ORDERED--PANI PURI")
        print("TOTAL :",cd69)
    elif c==7 and d==10:
        cd70=a7+a10
        print("YOU HAVE ORDERED--GUJARATI THALI FIXED")
        print("YOU HAVE ORDERED--SHAHI AALOO")
        print("TOTAL :",cd70)
    elif c==8 and d==1:
        cd71=a8+a1
        print("YOU HAVE ORDERED--UTTAPAM")
        print("YOU HAVE ORDERED--PANEER TIKKA MASALA")
        print("TOTAL :",cd71)
    elif c==8 and d==2:
        cd72=a8+a2
        print("YOU HAVE ORDERED--UTTAPAM")
        print("YOU HAVE ORDERED--PANEER BHURJEE")
        print("TOTAL :",cd72)
    elif c==8 and d==3:
        cd73=a8+a3
        print("YOU HAVE ORDERED--UTTAPAM")
        print("YOU HAVE ORDERED--MASALA DHOSA")
        print("TOTAL :",cd73)
    elif c==8 and d==4:
        cd74=a8+a4
        print("YOU HAVE ORDERED--UTTAPAM")
        print("YOU HAVE ORDERED--CHEESE CHILI MASALA DHOSA")
        print("TOTAL :",cd74)
    elif c==8 and d==5:
        cd75=a8+a5
        print("YOU HAVE ORDERED--UTTAPAM")
        print("YOU HAVE ORDERED--CHINESE BHEL")
        print("TOTAL :",cd75)
    elif c==8 and d==6:
        cd76=a8+a6
        print("YOU HAVE ORDERED--UTTAPAM")
        print("YOU HAVE ORDERED--MANCHURIYAN DRY")
        print("TOTAL :",cd76)
    elif c==8 and d==7:
        cd77=a8+a7
        print("YOU HAVE ORDERED--UTTAPAM")
        print("YOU HAVE ORDERED--GURAJATI THALI FIXED")
        print("TOTAL :",cd77)
    elif c==8 and d==8:
        cd78=a8+a8
        print("YOU HAVE ORDERED--UTTAPAM")
        print("TOTAL :",cd78)
    elif c==8 and d==9:
        cd79=a8+a9
        print("YOU HAVE ORDERED--UTTAPAM")
        print("YOU HAVE ORDERED--PANI PURI")
        print("TOTAL :",cd79)
    elif c==8 and d==10:
        cd80=a8+a10
        print("YOU HAVE ORDERED--UTTAPAM")
        print("YOU HAVE ORDERED--SHAHI AALOO")
        print("TOTAL :",cd80)
    elif c==9 and d==1:
        cd81=a9+a1
        print("YOU HAVE ORDERED--PANI PURI")
        print("YOU HAVE ORDERED--PANEER TIKKA MASALA")
        print("TOTAL :",cd81)
    elif c==9 and d==2:
        cd82=a9+a2
        print("YOU HAVE ORDERED--PANI PURI")
        print("YOU HAVE ORDERED--PANEER BHURJEE")
        print("TOTAL :",cd82)
    elif c==9 and d==3:
        cd83=a9+a3
        print("YOU HAVE ORDERED--PANI PURI")
        print("YOU HAVE ORDERED--MASALA DHOSA")
        print("TOTAL :",cd83)
    elif c==9 and d==4:
        cd84=a9+a4
        print("YOU HAVE ORDERED--PANI PURI")
        print("YOU HAVE ORDERED--CHEESE CHILI MASALA DHOSA")
        print("TOTAL :",cd84)
    elif c==9 and d==5:
        cd85=a9+a5
        print("YOU HAVE ORDERED--PANI PURI")
        print("YOU HAVE ORDERED--CHINESE BHEL")
        print("TOTAL :",cd85)
    elif c==9 and d==6:
        cd86=a9+a6
        print("YOU HAVE ORDERED--PANI PURI")
        print("YOU HAVE ORDERED--MANCHURIYAN DRY")
        print("TOTAL :",cd86)
    elif c==9 and d==7:
        cd87=a9+a7
        print("YOU HAVE ORDERED--PANI PURI")
        print("YOU HAVE ORDERED--GUJARATI THALI FIXED")
        print("TOTAL :",cd87)
    elif c==9 and d==8:
        cd88=a9+a8
        print("YOU HAVE ORDERED--PANI PURI")
        print("YOU HAVE ORDERED--UTTAPAM")
        print("TOTAL :",cd88)
    elif c==9 and d==9:
        cd89=a9+a9
        print("YOU HAVE ORDERED--PANI PURI X 2")
        print("TOTAL :",cd89)
    elif c==9 and d==10:
        cd90=a9+a10
        print("YOU HAVE ORDERED--PANI PURI")
        print("YOU HAVE ORDERED--SHAHI AALOO")
        print("TOTAL :",cd90)
    elif c==10 and d==1:
        cd91=a10+a1
        print("YOU HAVE ORDERED--SHAHI AALOO")
        print("YOU HAVE ORDERED--PANEER TIKKA MASALA")
        print("TOTAL :",cd91)
    elif c==10 and d==2:
        cd92=a10+a2
        print("YOU HAVE ORDERED--SHAHI AALOO")
        print("YOU HAVE ORDERED--PANEER BHURJEE")
        print("TOTAL :",cd92)
    elif c==10 and d==3:
        cd93=a10+a3
        print("YOU HAVE ORDERED--SHAHI AALOO")
        print("YOU HAVE ORDERED--MASALA DHOSA")
        print("TOTAL :",cd93)
    elif c==10 and d==4:
        cd94=a10+a4
        print("YOU HAVE ORDERED--SHAHI AALOO")
        print("YOU HAVE ORDERED--CHEESE CHILI MASALA DHOSA")
        print("TOTAL :",cd94)
    elif c==10 and d==5:
        cd95=a10+a5
        print("YOU HAVE ORDERED--SHAHI AALOO")
        print("YOU HAVE ORDERED--CHINESE BHEL")
        print("TOTAL :",cd95)
    elif c==10 and d==6:
        cd96=a10+a6
        print("YOU HAVE ORDERED--SHAHI AALOO")
        print("YOU HAVE ORDERED--MANCHURIYAN DRY")
        print("TOTAL :",cd96)
    elif c==10 and d==7:
        cd97=a10+a7
        print("YOU HAVE ORDERED--SHAHI AALOO")
        print("YOU HAVE ORDERED--GUJARATI THALI FIXED")
        print("TOTAL :",cd97)
    elif c==10 and d==8:
        cd98=a10+a8
        print("YOU HAVE ORDERED--SHAHI AALOO")
        print("YOU HAVE ORDERED--UTTAPAM")
        print("TOTAL :",cd98)
    elif c==10 and d==9:
        cd99=a10+a9
        print("YOU HAVE ORDERED--SHAHI AALOO")
        print("YOU HAVE ORDERED--PANI PURI")
        print("TOTAL :",cd99)
    elif c==10 and d==10:
        cd100=a10+a10
        print("YOU HAVE ORDERED--SHAHI AALOO X 2")
        print("TOTAL :",cd100)
elif a!=[1,2]:
    print("ERROR ! PLEASE INPUT AS PER GIVEN LIST(1 or 2 people only allowed)")
# Out:
# NOTE--WE ONLY TAKE 2 ORDERS AT A TIME. THANK YOU !!
# %%%LIST OF ITEMS%%%%         PRIZE      CODE
# -PANEER TIKKA MASALA          350         1
# -PANEER BHURJEE               290         2
# -MASALA DHOSA                 120         3
# -CHEESE CHILLI MASALA DHOSA   150         4
# -CHINESE BHEL                 110         5
# -MANCHURIYAN DRY              90          6
# -GUJARATI THALI FIXED         250         7
# -UTTAPAM                      100         8
# -PANI PURI                    30          9
# -SHAHI AALOO                  70          10
