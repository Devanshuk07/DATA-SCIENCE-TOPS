# %%
#Creating A Pandas Data Frame and Using Sample Data Sets.

# %%
import pandas as pd
a=pd.DataFrame({"Student":['devanshu','jay','vijay','raj','popat'],
               "Age":[20,22,24,26,28],
               "Roll no":[1,2,3,4,5,],
               })
print(a)
# Out:
#     Student  Age  Roll no
# 0  devanshu   20        1
# 1       jay   22        2
# 2     vijay   24        3
# 3       raj   26        4
# 4     popat   28        5
