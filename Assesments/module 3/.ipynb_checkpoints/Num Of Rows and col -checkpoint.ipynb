# %%
#  Write the code to show the number of rows and columns in data frame.

# %%
import pandas as pd
a=pd.read_csv("10000_rows_12_columns.csv")
print(a)
# Out:
#      text_col_1 text_col_2 text_col_3 text_col_4 text_col_5 text_col_6  \
# 0      CRWemwKa   WivoptKS   nJROWWGy   UMIXmzUz   VRDrczFq   YPNHdWvw
# 1      LEgsaZDG   WHOHODKG   aHSkktbU   UVcIRSms   UKwenmKJ   vRdbDVyA
# 2      yhbWvyDw   tANXxxuU   ucGWxHmr   iSigaTVk   TNZvNBoS   KGjAFnog
# 3      CMgoBUry   PzoMjBSR   jGfjIGwU   lgTXZjke   SrzLWQVW   gnvcPafE
# 4      NjUIVYtn   IOrbboXC   CtXwhDLj   cNCfoVIV   vcOfOSSH   yZebWrhz
# ...         ...        ...        ...        ...        ...        ...
# 9995   rHOWdguR   ENMXdiae   qBCqhOkV   pmpbHqkh   OArpEJFP   idjCoIFC
# 9996   yFwMOFCz   LQyJHpjJ   FCWpYlAo   DoEiOFqZ   YycsrdIh   XVSroYPR
# 9997   pOtncRDh   pZBxZxpo   aPQIPysO   AoPqVWpn   fdxcsmNf   hlpinwnu
# 9998   LGAjkGdU   nvkMaRsU   ZTLHXpMg   DeznubxR   PJZOuzUE   qbTQoueU
# 9999   OOHQhxuM   PZVwZvwU   mIhvuQpA   oWosgusY   iJVcdsRS   HQAcZuci
#
#       num_col_1  num_col_2  num_col_3  num_col_4  num_col_5  num_col_6
# ...
